# %% [markdown]
# <a href="https://colab.research.google.com/github/harinikoya-dot/Genrative-AI/blob/main/Generative_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Pass shape as a tuple
data = np.random.random((100, 2))

df = pd.DataFrame(data, columns=['X', 'Y'])
plt.scatter(df['X'], df['Y'])
plt.show()

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize

text = "Artificial Intelligence is changing the world"
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Artificial Intelligence is changing the world']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
